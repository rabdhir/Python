# %%
import pandas
df1=pandas.read_json("D:\\Projects\\Python\\Data\\supermarkets\\supermarkets.json")
df1.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3=pandas.read_csv("D:\\Projects\\Python\\Data\\supermarkets\\supermarkets_commas.txt")
df3
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees
# 0       Madeira          8
# 1   Bready Shop         15
# 2   Super River         25
# 3    Ben's Shop         10
# 4       Sanchez         12
# 5    Richvalley         20

# %%
df5=pandas.read_csv("D:\\Projects\\Python\\Data\\supermarkets\\supermarkets_semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees
# 0       Madeira          8
# 1   Bready Shop         15
# 2   Super River         25
# 3    Ben's Shop         10
# 4       Sanchez         12
# 5    Richvalley         20

# %%
df5
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees
# 0       Madeira          8
# 1   Bready Shop         15
# 2   Super River         25
# 3    Ben's Shop         10
# 4       Sanchez         12
# 5    Richvalley         20

# %%
len(df5.index)
# Out:
# 6

# %%
df5["Continent"]=df5["Country"]+ "," + "North America"
df5
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees           Continent
# 0       Madeira          8   USA,North America
# 1   Bready Shop         15   USA,North America
# 2   Super River         25   USA,North America
# 3    Ben's Shop         10   USA,North America
# 4       Sanchez         12   USA,North America
# 5    Richvalley         20   USA,North America

# %%
df5.set_index("Address")
# Out:
#                  ID            City             State Country          Name  \
# Address
#  3666 21st St     1   San Francisco          CA 94114     USA       Madeira
#  735 Dolores St   2   San Francisco          CA 94119     USA   Bready Shop
#  332 Hill St      3   San Francisco  California 94114     USA   Super River
#  3995 23rd St     4   San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5   San Francisco        California     USA       Sanchez
# 551 Alvarado St   6   San Francisco          CA 94114     USA    Richvalley
#
#                  Employees           Continent
# Address
#  3666 21st St            8   USA,North America
#  735 Dolores St         15   USA,North America
#  332 Hill St            25   USA,North America
#  3995 23rd St           10   USA,North America
# 1056 Sanchez St         12   USA,North America
# 551 Alvarado St         20   USA,North America

# %%
df5.iloc[3,:4]
# Out:
# ID                      4
# Address      3995 23rd St
# City        San Francisco
# State            CA 94114
# Name: 3, dtype: object

# %%
df5.drop("City",1)
# Out:
#    ID          Address             State Country          Name  Employees  \
# 0   1     3666 21st St          CA 94114     USA       Madeira          8
# 1   2   735 Dolores St          CA 94119     USA   Bready Shop         15
# 2   3      332 Hill St  California 94114     USA   Super River         25
# 3   4     3995 23rd St          CA 94114     USA    Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA       Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA    Richvalley         20
#
#             Continent
# 0   USA,North America
# 1   USA,North America
# 2   USA,North America
# 3   USA,North America
# 4   USA,North America
# 5   USA,North America

# %%
df5
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees           Continent
# 0       Madeira          8   USA,North America
# 1   Bready Shop         15   USA,North America
# 2   Super River         25   USA,North America
# 3    Ben's Shop         10   USA,North America
# 4       Sanchez         12   USA,North America
# 5    Richvalley         20   USA,North America

# %%
df5.set_index("Address")
# Out:
#                  ID            City             State Country          Name  \
# Address
#  3666 21st St     1   San Francisco          CA 94114     USA       Madeira
#  735 Dolores St   2   San Francisco          CA 94119     USA   Bready Shop
#  332 Hill St      3   San Francisco  California 94114     USA   Super River
#  3995 23rd St     4   San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5   San Francisco        California     USA       Sanchez
# 551 Alvarado St   6   San Francisco          CA 94114     USA    Richvalley
#
#                  Employees           Continent
# Address
#  3666 21st St            8   USA,North America
#  735 Dolores St         15   USA,North America
#  332 Hill St            25   USA,North America
#  3995 23rd St           10   USA,North America
# 1056 Sanchez St         12   USA,North America
# 551 Alvarado St         20   USA,North America

# %%
df5.shape
# Out:
# (6, 8)

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeFarm',
#  'GeocoderDotUS',
#  'GoogleV3',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'NaviData',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Photon',
#  'Point',
#  'What3Words',
#  'YahooPlaceFinder',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'units',
#  'util']

# %%
df5
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees           Continent
# 0       Madeira          8   USA,North America
# 1   Bready Shop         15   USA,North America
# 2   Super River         25   USA,North America
# 3    Ben's Shop         10   USA,North America
# 4       Sanchez         12   USA,North America
# 5    Richvalley         20   USA,North America

# %%
df5_t=df5.T

# %%
df5_t
# Out:
#                             0                   1                  2  \
# ID                          1                   2                  3
# Address          3666 21st St      735 Dolores St        332 Hill St
# City            San Francisco       San Francisco      San Francisco
# State                CA 94114            CA 94119   California 94114
# Country                   USA                 USA                USA
# Name                  Madeira         Bready Shop        Super River
# Employees                   8                  15                 25
# Continent   USA,North America   USA,North America  USA,North America
#
#                            3                  4                  5
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# ...

# %%
from geopy.geocoders import Nominatim

# %%
nom=Nominatim()

# %%
nom.geocode("1787 Pine Hollow Circle, San Jose, California, 95133")
# Out:
# Location(1787, Pine Hollow Circle, Berryessa, San José, Santa Clara County, California, 95133, United States of America, (37.3675783948629, -121.862758481798, 0.0))

# %%
nom1=Nominatim()

# %%
nom1.geocode("33 Jeram Masjid, Bakri, Muar, Johor 84000, Malaysia")

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees
# 0       Madeira          8
# 1   Bready Shop         15
# 2   Super River         25
# 3    Ben's Shop         10
# 4       Sanchez         12
# 5    Richvalley         20

# %%
df["Address"]=df["Address"]+", "+df["City"] + ", "+ df["State"]+ ", "+df["Country"]
df
# Out:
#    ID                                            Address            City  \
# 0   1   3666 21st St, San Francisco,  CA 94114,  USA,...   San Francisco
# 1   2   735 Dolores St, San Francisco,  CA 94119,  US...   San Francisco
# 2   3   332 Hill St,  San Francisco, California 94114...   San Francisco
# 3   4   3995 23rd St,  San Francisco,  CA 94114, USA,...   San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...   San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...   San Francisco
#
#               State Country          Name  Employees
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address            City  \
# 0   1   3666 21st St, San Francisco,  CA 94114,  USA,...   San Francisco
# 1   2   735 Dolores St, San Francisco,  CA 94119,  US...   San Francisco
# 2   3   332 Hill St,  San Francisco, California 94114...   San Francisco
# 3   4   3995 23rd St,  San Francisco,  CA 94114, USA,...   San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...   San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...   San Francisco
#
#               State Country          Name  Employees Coordinates
# 0          CA 94114     USA       Madeira          8        None
# 1          CA 94119     USA   Bready Shop         15        None
# 2  California 94114     USA   Super River         25        None
# 3          CA 94114     USA    Ben's Shop         10        None
# 4        California     USA       Sanchez         12        None
# 5          CA 94114     USA    Richvalley         20        None

# %%
df.Coordinates[0].latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-c10228f95433> in <module>()
# ----> 1 df.Coordinates[0].latitude
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                            Address            City  \
# 0   1   3666 21st St, San Francisco,  CA 94114,  USA,...   San Francisco
# 1   2   735 Dolores St, San Francisco,  CA 94119,  US...   San Francisco
# 2   3   332 Hill St,  San Francisco, California 94114...   San Francisco
# 3   4   3995 23rd St,  San Francisco,  CA 94114, USA,...   San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...   San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...   San Francisco
#
#               State Country          Name  Employees Coordinates Latitude  \
# 0          CA 94114     USA       Madeira          8        None     None
# 1          CA 94119     USA   Bready Shop         15        None     None
# 2  California 94114     USA   Super River         25        None     None
# 3          CA 94114     USA    Ben's Shop         10        None     None
# 4        California     USA       Sanchez         12        None     None
# ...
